# %%
# "input" 代表資料輸入
name = input('你的名字是? ')
print('My name is', name)
# Out:
# 你的名字是? Jean
# My name is Jean

# %%
age = input('你的年紀是? ')
print('My age is ' + age + ' 生於', 2021-30)
# Out:
# 你的年紀是? 29
# My age is 29 生於 1991

# %%
# 同上範例，帶入age變數
age = input('你的年紀是? ')
print('My age is ' + age + ' 生於', 2021-int(age))
# Out:
# 你的年紀是? 30
# My age is 30 生於 1991

# %%
# Practice
a = input("輸入整數1a: ") # string
b = input("輸入整數1b: ") # string
c = int(input("int輸入c:")) # string --> int
d = int(input("int輸入d:")) # string --> int
f = a + b # 字串串接
g = c + d # 數字加法
print(f)
print(g)
# Out:
# 輸入整數1a: 55
# 輸入整數1b: 66
# int輸入c:12
# int輸入d:21
# 5566
# 33

# %%
# Practice
c = int(input("int輸入c:")) # string --> int
d = int(input("int輸入d:")) # string --> int
g = c + d # 整數相加
print("Int相加:", g)

h = float(input("float輸入h:")) # string --> float
i = float(input("float輸入i:")) # string --> float
j = h + d # 浮點數相加
print("Float相加:", j)
# Out:
# int輸入c:29
# int輸入d:29
# Int相加: 58
# float輸入h:16
# float輸入i:16
# Float相加: 45.0

# %%
# Practice
a = input("輸入字串: ") # 亦可使用type函數查詢資料型態
print(a, a.__class__)
a = input("輸入整數: ")
print(a, a.__class__)
a = float(input("float輸入浮點數: "))
print(a, a.__class__)
a = int(input("int輸入整數:"))
print(a, a.__class__)
a = int(input("int輸入字串:")) # 文字無法強制轉換為數字
print(a, a.__class__)
# Out:
# 輸入字串: Jean
# Jean <class 'str'>
# 輸入整數: 16
# 16 <class 'str'>
# float輸入浮點數: 16.0
# 16.0 <class 'float'>
# int輸入整數:16
# 16 <class 'int'>
# int輸入字串:Wang
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7a5b34c77365> in <module>()
#       8 a = int(input("int輸入整數:"))
#       9 print(a, a.__class__)
# ---> 10 a = int(input("int輸入字串:"))
#      11 print(a, a.__class__)
#
# ValueError: invalid literal for int() with base 10: 'Wang'

# %%
age = 18

if age >= 18:
  print('歡迎光臨')
else:
  print('下次再來')
  print('年紀',age)
# Out:
# 歡迎光臨

# %%
age = 16

if age >= 18:
  print('歡迎光臨')
else:
  print('下次再來')
  print('年紀:',age)
# Out:
# 下次再來
# 年紀: 16

# %%
age = int(input('How old are you ?')) # 使用input輸入，須留意資料型態

if age >= 18:
  print('歡迎光臨')
else:
  pring('下次再來')
# Out:
# How old are you ?29
# 歡迎光臨

# %%
# 關係運算（留意“等號”用法）
height = 189 # Assign 宣告變數
height == 189 # Equal 布林值

# %%
# 補充：boolean，除了0以外，其他整數都是True
bool(1), bool(0), bool(2), bool(-1)
# Out:
# (True, False, True, True)

# %%
# 補充：True、False相加，會轉換成int後才進行

False + True
# Out:
# 1

# %%
# Practice＿條件成立
a = 21
if a > 18:
  print('大於18')
print('執行結束')
# Out:
# 大於18
# 執行結束

# %%
# Practice＿條件不成立
a = 11
if a > 18:
  print('大於18')
print('執行結束')
# Out:
# 執行結束

# %%
# 補充：“!=”為不等於

a = 12

if a!=12:
  print('不等於12')
else:
  print('等於12')

print('執行結束')
# Out:
# 等於12
# 執行結束

# %%
# elif為雙向選擇，第二條件成立時執行（大-小 or 小-大排列）

age = 19

if age > 18:
  print('大學')
elif age > 15:
  print('高中')
elif age > 12:
  print('國中')
elif age > 6:
  print('國小')
else:
  print('幼兒園')
# Out:
# 大學

# %%
# Practice 區間寫法，另可省略else

age = 21

if 12 < age <= 18:
  print('12+...18')
elif 18 < age:
  print('18+...')
elif age <= 12:
  print('...12')
# Out:
# 18+...

# %%
# Practice 使用直覺方式進行邏輯分析

a=14

if a >= 12 and a < 18:
    print("ok-1")
else:
    print("cancel- 1")

if 12 <= a < 18:
    print("ok-2")
else:
    print("cancel- 2")

if not a > 18:
    print("ok-3")
else:
    print("cancel- 3")
# Out:
# ok-1
# ok-2
# ok-3

# %%
# Practice 根據上述練習題的排序，改為小-大

age = 13

if age < 6:
  print('幼兒園')
elif age < 12:
  print('國小')
elif age < 15:
  print('國中')
elif age < 18:
  print('高中')
else:
  print('大學')
# Out:
# 國中

# %%
# Practice 較完整寫法，排除程式中有不合理的情況

age = -1

if 0 <= age < 6:
  print('幼兒園')
elif 6 <= age < 12:
  print('國小')
elif 12 <= age < 15:
  print('國中')
elif 15 <= age < 18:
  print('高中')
elif 18 < age:
  print('大學')
else:
  print('數值錯誤')
# Out:
# 數值錯誤

# %%
# 個人BMI計算 (round四捨五入)

height = 1.65
kgw = 52
bmi = round(kgw / (height * height),1)

if bmi < 18.5:
  print('太輕')
elif 18.5 <= bmi < 25:
  print('正常')
elif 25 <= bmi < 30:
  print('過重')
elif bmi > 30:
  print('肥胖')
print(bmi)
# Out:
# 正常
# 19.1
