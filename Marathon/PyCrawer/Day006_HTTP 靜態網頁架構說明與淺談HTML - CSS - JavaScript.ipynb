# %% [markdown]
# # HTTP 靜態網頁架構說明
#
# * 認識靜態網頁的溝通架構與運作原理
# * HTML、CSS、JavaScript 在網頁中扮演的角色
# * 網頁中定位資料的方法

# %% [markdown]
# ## 作業目標
#
# 1. （簡答題）請問目前提到的這種基於 HTTP 一來一回的網頁傳輸方式，有哪些缺點及問題？
# 2. （簡答題）網頁中使用的 JavaScipt 程式語言，跟我們一般使用的 Python 在執行上有什麼不同。

# %% [markdown]
# ### 1.（簡答題）請問目前提到的這種基於 HTTP 一來一回的網頁傳輸方式，有哪些缺點及問題？

# %%
'''
HTTP傳輸協定是基於Request/Response概念，一來一回的傳輸方式，其可能產生的問題：1.一次僅能處理一個Request，造成時間延遲問題 2.現今網路應用廣泛，檔案容量大，影響Internet的流量，傳輸速度效率不足
'''
# Out:
# '\nHTTP傳輸協定是基於Request/Response概念，一來一回的傳輸方式，其可能產生的問題：1.一次僅能處理一個Request，造成時間延遲問題 2.現今網路應用廣泛，檔案容量大，影響Internet的流量，傳輸速度效率不足\n'

# %% [markdown]
# ### 2. （簡答題）網頁中使用的 JavaScipt 程式語言，跟我們一般使用的 Python 在執行上有什麼不同。

# %%
'''
1.程式碼撰寫方式 2.語法（資料型態不同）3.應用領域
'''
# Out:
# '\n1.程式碼撰寫方式 2.語法（資料型態不同）3.應用領域\n'
