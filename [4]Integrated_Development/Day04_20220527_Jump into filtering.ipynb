# %% [markdown]
# ## Sobel_MNIST Dataset

# %%
# from keras.models import Sequential
from keras.datasets import mnist

# 載入MNIST資料庫的訓練資料，並自動分為『訓練組』及『測試組』
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[1].reshape(28, 28), cmap = 'gray')
plt.show()

# %%
from skimage.filters import sobel
mnist_sobel = sobel(image = X_train[1].reshape(28, 28))
plt.imshow(mnist_sobel, cmap = 'gray')
plt.show()

# %%
# 錯誤方式
from skimage.filters import sobel
mnist_sobel_all = sobel(image = X_train[:])
plt.imshow(mnist_sobel_all[1], cmap = 'gray')
plt.show()

# %%
# 人臉邊界
import matplotlib.pyplot as plt
from skimage.filters import sobel
andy_org = plt.imread('andy.jpg')
plt.imshow(andy_org)
plt.show()

thresh = 110 / 255.0
from skimage import io
andy = io.imread('andy.jpg', as_gray = True)

binary = (andy > thresh )

plt.imshow(binary, cmap = 'gray')
plt.show()

andy_sobel = sobel(image = binary)
plt.imshow(andy_sobel)
plt.show()

# help(sobel)

# %% [markdown]
# ## Gaussian_MNIST Dataset

# %%
# from keras.models import Sequential
from keras.datasets import mnist
# 載入MNIST資料庫的訓練資料，並自動分為『訓練組』及『測試組』
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[0].reshape(28, 28), cmap = 'gray')
plt.show()

# %%
from skimage.filters import gaussian
mnist_gaussian = gaussian(image = X_train[0].reshape(28, 28), sigma = 1)
plt.imshow(mnist_gaussian, cmap = 'gray')
plt.show()

# %%
# 錯誤方式
from skimage.filters import gaussian
mnist_gaussian_all = gaussian(image = X_train[:], sigma = 1)
plt.imshow(mnist_gaussian_all[0], cmap = 'gray')
plt.show()

# %% [markdown]
# ## Gaussian Image

# %%
from skimage import color, io
andy = io.imread('andy.jpg', as_gray = False)
io.imshow(andy)
io.show()

# %%
from skimage.filters import gaussian
from matplotlib import pyplot as plt
sigma = range(0, 10, 2)
for s in sigma:
    gaussian_sobel = skimage.filters.gaussian(andy, sigma = s, channel_axis = -1)
    plt.imshow(gaussian_sobel)
    plt.title('Sigma = ' + str(s))
    plt.show()

# %%
from skimage.filters import gaussian
from matplotlib import pyplot as plt
mode = ['reflect', 'constant', 'nearest', 'mirror', 'wrap']
for m in mode:
    gaussian_sobel = gaussian(andy, sigma = 2, channel_axis = -1, mode = m)
    plt.title('Mode '+ m)
    plt.imshow(gaussian_sobel)
    plt.show()

# %% [markdown]
# ## Edge Detection

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
def show_image(image, title = 'Image', cmap_type = 'gray', interpolation = None):
    plt.imshow(image, cmap = cmap_type)    
    plt.title(title)
    plt.axis('off')
    plt.show()
       
soaps_image = plt.imread('soaps_image.jpg')
plt.imshow(soaps_image)
plt.show()

# %%
# Import the color module
from skimage import color

# Import the filters module and sobel function
from skimage.filters import sobel

# Make the image grayscale
soaps_image_gray = color.rgb2gray(soaps_image)

# Apply edge detection filter
edge_sobel = sobel(soaps_image_gray)

# Show original and resulting image to compare
show_image(soaps_image, "Original")
show_image(edge_sobel, "Edges with Sobel")

# %%
import matplotlib.pyplot as plt
def plot_comparision(original, filtered, title_filtered):
    fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (32, 8), sharex = True, sharey = True)
    ax1.imshow(original, cmap = plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    
    ax2.imshow(filtered, cmap = plt.cm.gray)
    ax2.set_title(title_filtered)
    ax2.axis('off')
    
building_image = plt.imread('building_image.jpg')
plt.imshow(building_image)
plt.show()

# %%
# Import Gaussian filter
from skimage.filters import gaussian

# Apply filter
gaussian_image = gaussian(building_image, channel_axis = -1)

# Show original and resulting image to compare
show_image(building_image, "Original")
show_image(gaussian_image, "Reduced sharpness Gaussian")

# %%
original, filtered = plt.imread('building_image-original.jpg'), \
                     plt.imread('building_image-reduced sharpness Gaussian.jpg')

plot_comparision(original, filtered, 'Gaussian filtered')

# %% [markdown]
# ## Sobel_MNIST Dataset

# %%
# 導入函式庫
import numpy as np
import keras
# from keras.models import Sequential
from keras.datasets import mnist
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
from matplotlib import pyplot as plt
from datetime import datetime

# %%
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu     <--
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# skimage.filters.thresholding.threshold_local    <--
###### Local
# filters.threshold_local(
#     image,
#     block_size,
#     method='gaussian',
#     offset=0,
#     mode='reflect',
#     param=None,
#     cval=0)
# from skimage import filters
# local_thresh = filters.threshold_local(image = X_train[0].reshape(28, 28), 
#                                        block_size = 5, 
#                                        offset = 1)
# print(local_thresh.shape)
# binary = X_train[0].reshape(28, 28) > local_thresh
# plt.imshow(binary, cmap = 'gray')
# plt.show()

###### Global
# from skimage.filters import threshold_otsu
# otsu_value = threshold_otsu(andy)
# print(otsu_value)
# otus_andy = andy > otsu_value
# plt.imshow(otus_andy, cmap = 'gray')
# plt.show()

# %%
# 重新載入資料
# 載入MNIST資料庫的訓練資料，並自動分為『訓練組』及『測試組』
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# 首次處理針對 X_train, X_test
X_train_sobel, X_test_sobel = [], []
# from skimage.filters import thresholding# .threshold_otsu
from skimage.filters import sobel
from tqdm import tqdm

for i in tqdm(range(X_train.shape[0])):
    img = sobel(image = X_train[i].reshape(28, 28))
    X_train_sobel.append(img)

for i in tqdm(range(X_test.shape[0])):
    img = sobel(image = X_test[i].reshape(28, 28))
    X_test_sobel.append(img)  

# 數據二次處理
X_train, X_test = np.array(X_train_sobel), np.array(X_test_sobel)
print(X_train.shape, X_test.shape)
# 顯示
plt.imshow(X_train[0], cmap = 'gray')
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 6986.42it/s]
# (60000, 28, 28) (10000, 28, 28)

# %%
# 建立簡單的線性執行的模型
model = keras.models.Sequential()
# Add Input layer, 隱藏層(hidden layer)有256個輸出變數
model.add(Dense(units = 128, input_dim = 784, kernel_initializer = 'normal', activation = 'relu'))
# Add output layer
model.add(Dense(units = 10, kernel_initializer = 'normal', activation = 'softmax'))

# 選擇損失函數、優化方法及成效衡量方式
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 將training的label進行one-hot encoding
y_TrainOneHot = np_utils.to_categorical(y_train) 
y_TestOneHot = np_utils.to_categorical(y_test) 

# 將training的input資料轉為二維
X_train_2D = X_train.reshape(60000, 28 * 28).astype('float32')
X_test_2D = X_test.reshape(10000, 28 * 28).astype('float32')

x_Train_norm = X_train_2D / 255.0
x_Test_norm = X_test_2D / 255.0

# 進行訓練，訓練過程會存在train_history變數中
train_history = model.fit(x = x_Train_norm, y = y_TrainOneHot, 
                          validation_split = 0.2, epochs = 10, 
                          batch_size = 800, verbose = 2)
# Out:
# Epoch 1/10
# 60/60 - 1s - loss: 2.2939 - accuracy: 0.1252 - val_loss: 2.2787 - val_accuracy: 0.1060 - 1s/epoch - 17ms/step
# Epoch 2/10
# 60/60 - 1s - loss: 2.2437 - accuracy: 0.2669 - val_loss: 2.1928 - val_accuracy: 0.3899 - 657ms/epoch - 11ms/step
# Epoch 3/10
# 60/60 - 1s - loss: 2.1266 - accuracy: 0.4332 - val_loss: 2.0415 - val_accuracy: 0.4645 - 694ms/epoch - 12ms/step
# Epoch 4/10
# 60/60 - 1s - loss: 1.9619 - accuracy: 0.4858 - val_loss: 1.8607 - val_accuracy: 0.5291 - 702ms/epoch - 12ms/step
# Epoch 5/10
# 60/60 - 1s - loss: 1.7844 - accuracy: 0.5553 - val_loss: 1.6817 - val_accuracy: 0.5863 - 631ms/epoch - 11ms/step
# Epoch 6/10
# 60/60 - 0s - loss: 1.6166 - accuracy: 0.6066 - val_loss: 1.5184 - val_accuracy: 0.6329 - 480ms/epoch - 8ms/step
# Epoch 7/10
# 60/60 - 1s - loss: 1.4678 - accuracy: 0.6422 - val_loss: 1.3763 - val_accuracy: 0.6823 - 542ms/epoch - 9ms/step
# Epoch 8/10
# ...

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Test_norm, y_TestOneHot)
print()
print("\t[Info] Accuracy of testing data = {:2.1f}%".format(scores[1] * 100.0))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0863 - accuracy: 0.7308
#
# 	[Info] Accuracy of testing data = 73.1%

# %%
# 顯示訓練成果(分數)
scores = model.evaluate(x_Train_norm, y_TrainOneHot)
print()
print("\t[Info] Accuracy of training data = {:2.1f}%".format(scores[1] * 100.0))
# Out:
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.0938 - accuracy: 0.7198
#
# 	[Info] Accuracy of training data = 72.0%

# %%
# %matplotlib inline
# accuracy chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['accuracy'], color = 'red')
plt.plot(train_history.history['val_accuracy'], color = 'blue')
plt.grid()
plt.show()

# %%
# %matplotlib inline
# loss chart
import matplotlib.pyplot as plt
plt.plot(train_history.history['loss'], color = 'red')
plt.plot(train_history.history['val_loss'], color = 'blue')
plt.grid()
plt.show()
