# %%
# 外型型態Morphology先轉為Gray，才可以處理
# from skimage import morphology
# morphology.binary_erosion(image, selem)
# morphology.binary_dilation(image)

# %%
from skimage import morphology
print(dir(morphology))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_convex_hull', '_extrema_cy', '_flood_fill', '_flood_fill_cy', '_grayreconstruct', '_max_tree', '_skeletonize', '_skeletonize_3d_cy', '_skeletonize_cy', '_util', 'area_closing', 'area_opening', 'ball', 'binary', 'binary_closing', 'binary_dilation', 'binary_erosion', 'binary_opening', 'black_tophat', 'closing', 'convex_hull', 'convex_hull_image', 'convex_hull_object', 'cube', 'diameter_closing', 'diameter_opening', 'diamond', 'dilation', 'disk', 'ellipse', 'erosion', 'extrema', 'flood', 'flood_fill', 'footprint_from_sequence', 'footprints', 'gray', 'grayreconstruct', 'h_maxima', 'h_minima', 'isotropic', 'isotropic_closing', 'isotropic_dilation', 'isotropic_erosion', 'isotropic_opening', 'label', 'local_maxima', 'local_minima', 'max_tree', 'max_tree_local_maxima', 'medial_axis', 'misc', 'octagon', 'octahedron', 'opening', 'reconstruction', 'rectangle', 'remove_small_holes', 'remove_small_objects', 'skeletonize', 'skeletonize_3d', 'square', 'star', 'thin', 'white_tophat']

# %%
a = %pwd
print(a)
# Out:
# C:\Python\Level_IV\Day07

# %%
from skimage import color, io
img = io.imread('./world_image_binary.jpg', as_gray = True)
io.imshow(img, cmap = 'gray')

# %%
from skimage import morphology
scan = morphology.rectangle(4, 8)

# %%
import matplotlib.pyplot as plt
andy_erosion = morphology.binary_erosion(img, scan)
plt.imshow(andy_erosion, cmap = 'gray')
plt.show()

# %% [markdown]
# ### Eroded Image
# Apply the morphological operation that will discard the pixels near the letter boundaries.

# %%
# Import the module from scikit-image.
# Apply the morphological operation for eroding away the boundaries of regions of foreground pixels.

# %matplotlib inline

# 準備作業
import matplotlib.pyplot as plt
def show_image(image, title = 'Image', cmap_type = 'gray', interpolation = None):
    plt.imshow(image, cmap = cmap_type)    
    plt.title(title)
    plt.axis('off')
    plt.show()
    
def plot_comparision(original, filtered, title_filtered):
    fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (32, 8), sharex = True, sharey = True)
    ax1.imshow(original, cmap = plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    
    ax2.imshow(filtered, cmap = plt.cm.gray)
    ax2.set_title(title_filtered)
    ax2.axis('off')

upper_r_image = plt.imread('./r5.png')

plt.imshow(upper_r_image)
plt.show()

# %%
# 轉灰階
from skimage import color
upper_r_image = color.rgb2gray(upper_r_image)

# %%
# Import the morphology module
from skimage import morphology

# Obtain the eroded shape 
eroded_image_shape = morphology.binary_erosion(upper_r_image) 

# See results
show_image(upper_r_image, 'Original')
show_image(eroded_image_shape, 'Eroded image')

# %% [markdown]
# ### Dilated Image
# Reduce the noise of a thresholded image using the dilation morphological operation.This operation, in a way, expands the objects in the image.

# %%
# Import the module.
# Obtain the binarized and dilated image, from the original image world_image.

world_image = plt.imread('./world_image_binary.jpg')
world_image.shape
# Out:
# (327, 640)

# %%
# Import the module
from skimage import morphology

# Obtain the dilated image 
dilated_image = morphology.binary_dilation(world_image)

# See results
show_image(world_image, 'Original')
show_image(dilated_image, 'Dilated image')
